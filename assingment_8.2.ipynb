# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()   #return a 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()  # return avalue of grapfh of int value
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes   #this is return to a data type value
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.Categorical(df['Pclass'])  #unique element
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df.iloc[0:2,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %% [markdown]
# Answer:

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2,3,4,5,6],'B':[1,3,5,4,2,8],'C':[9,7,6,8,4,3]
                  }, index=[i for i in range(1,len(df)*2,2) ])
df
# Out:
#     A  B  C
# 1   1  1  9
# 3   2  3  7
# 5   3  5  6
# 7   4  4  8
# 9   5  2  4
# 11  6  8  3

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.Values

# %% [markdown]
# Answer:

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Values': [10, 20, 30, 40, 50]})

# %%
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def sum_dataframe_columns():
    for i in range(3):
        dataframe = df['Values'][i]
        dataframe+= dataframe
    return dataframe
print(sum_dataframe_columns())
# Out:
# 60

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
import pandas as pd

# %%
df = pd.DataFrame({'test':['kapil','sudh','himanshu','datascience','python']})

# %%
def count_fn():
    for i in range(len(df['test'])):
        print(len(df['test'][i]))
count_fn()
# Out:
# 5
# 4
# 8
# 11
# 6

# %%
LIST = []
LIST.append(2)
LIST.append(3)

# %%
LIST
# Out:
# [2, 3]

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size returns the total number of elements in the DataFrame, which is equivalent to the product of the number of rows and the number of columns:
# example

# %%
import pandas as pd 
df = pd.DataFrame({'A':[1,2,3], 'B':[6,4,5]})
size_data = df.size
size_data
# df.shape[0]
# df.shape[1]
# dataFrame.size() product of row and columns
# Out:
# 6

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2,3,4,5], "B":[23,345,34,345,5]})
# DataFrame.shape returns a tuple that provides the dimensions of the DataFrame.
# The tuple contains two elements: the first element is the number of rows, and the second element is the number of columns.
# It is useful for quickly checking the size and shape of the DataFrame.
# Example: If you have a DataFrame with 3 rows and 4 columns, DataFrame.shape will return (3, 4).
print(df.shape[0], df.shape[1])
print(df.shape)
# Out:
# 5 2
# (5, 2)

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
import pandas as pd
df = pd.read_excel('Copy of LUSID Excel - Setting up your market data.xlsx')
# df = pd.read_excel('Copy of LUSID Excel - Setting up your market data.xlsx', sheet_name='Sheet1', header=1)
# df = pd.read_excel('Copy of LUSID Excel - Setting up your market data.xlsx', usecols=['Column1', 'Column2'])
# df = pd.read_excel('Copy of LUSID Excel - Setting up your market data.xlsx', dtype={'Column1': int, 'Column2': str})

# and various different path to read a excel file

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
import pandas as pd
df = pd.DataFrame({'Email':['hiddenkp19@gmail.com', 'jonb.dec@gmail.com', 'sudh0123@gmail.com','jokt.sekh@gmail.com', 'serun012@gmail.com']})
df
# Out:
#                   Email
# 0  hiddenkp19@gmail.com
# 1    jonb.dec@gmail.com
# 2    sudh0123@gmail.com
# 3   jokt.sekh@gmail.com
# 4    serun012@gmail.com

# %%
a =list(df['Email'])
a
# Out:
# ['hiddenkp19@gmail.com',
#  'jonb.dec@gmail.com',
#  'sudh0123@gmail.com',
#  'jokt.sekh@gmail.com',
#  'serun012@gmail.com']

# %%
string = list(df['Email'])
s = []
d = []
a=0
for i in string:
    for j in i:
        # print(j)
        if j!='@':
            s.append(j)
            # print(s)
    
        else:
            break
    
    d.append(len(s)-a)
    a = len(s)
# print(d)

a= [i for i in range(len(d))]
def count(x,a):
    b = string[a][:x]
    return b
    
    
a = list(map(count , d,a))
# print(a)


df['Username'] = a
print(df)
# Out:
#                   Email    Username
# 0  hiddenkp19@gmail.com  hiddenkp19
# 1    jonb.dec@gmail.com    jonb.dec
# 2    sudh0123@gmail.com    sudh0123
# 3   jokt.sekh@gmail.com   jokt.sekh
# 4    serun012@gmail.com    serun012

# %% [raw]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
#   A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
# Your function should select the following rows: A B C
# 1 8 2 7
# 4 9 1 2
# The function should return a new DataFrame that contains only the selected rows.

# %%
import pandas as pd

# %%
df = pd.DataFrame({'A':[3,8,6,2,9], 'B':[5,2,9,3,1], 'C':[1,7,4,5,2]})

# %%
N_df = df[(df['A']>5) & (df['B']<10)]
N_dataframe = pd.DataFrame(N_df)

# %%
N_dataframe
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
import pandas as pd
data = {'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# Function to calculate mean, median, and standard deviation
def calculate_statistics(df):
    values = df['Values']
    mean = values.mean()
    median = values.median()
    std_dev = values.std()
    return mean, median, std_dev

# Call the function to calculate statistics
mean_value, median_value, std_deviation  = calculate_statistics(df)
print("Mean:", mean_value)
print("Median:", median_value)
print("Standard Deviation:", std_deviation)
# Out:
# Mean: 30.0
# Median: 30.0
# Standard Deviation: 15.811388300841896

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
import pandas as pd

data = {'Date': pd.date_range(start='2023-01-01', periods=10, freq='D'),
        'Sales': [50, 45, 60, 55, 70, 65, 80, 75, 90, 85]}

df = pd.DataFrame(data)

def calculate_moving_average(df, window_size=7):
    df['MovingAverage'] = df['Sales'].rolling(window=window_size, min_periods=1).mean()
    return df

result_df = calculate_moving_average(df)

print(result_df)
# Out:
#         Date  Sales  MovingAverage
# 0 2023-01-01     50      50.000000
# 1 2023-01-02     45      47.500000
# 2 2023-01-03     60      51.666667
# 3 2023-01-04     55      52.500000
# 4 2023-01-05     70      56.000000
# 5 2023-01-06     65      57.500000
# 6 2023-01-07     80      60.714286
# 7 2023-01-08     75      64.285714
# 8 2023-01-09     90      70.714286
# 9 2023-01-10     85      74.285714

# %% [raw]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
import pandas as pd

data = {'Date': pd.date_range(start='2023-01-02', periods=5, freq='D')}
df = pd.DataFrame(data)

# Function to create the 'Weekday' column
def add_weekday_column(df):
    df['Weekday'] = df['Date'].dt.strftime('%A')
    return df

# Call the function to add the 'Weekday' column
result_df = add_weekday_column(df)

print(result_df)
# Out:
#         Date    Weekday
# 0 2023-01-02     Monday
# 1 2023-01-03    Tuesday
# 2 2023-01-04  Wednesday
# 3 2023-01-05   Thursday
# 4 2023-01-06     Friday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
import pandas as pd
data = {'Date': pd.date_range(start='2023-01-01', periods=50, freq='D')}
df = pd.DataFrame(data)

# Function to select rows within a date range
def select_rows_in_date_range(df, start_date, end_date):
    mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
    selected_rows = df[mask]
    return selected_rows

# Call the function to select rows within the date range
start_date = '2023-01-01'
end_date = '2023-01-31'
selected_df = select_rows_in_date_range(df, start_date, end_date)
print(selected_df)
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# 22 2023-01-23
# 23 2023-01-24
# 24 2023-01-25
# 25 2023-01-26
# 26 2023-01-27
# 27 2023-01-28
# 28 2023-01-29
# 29 2023-01-30
# 30 2023-01-31

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %%
import pandas as pd
